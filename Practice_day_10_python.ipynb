# %% [markdown]
# # Python Important Methods

# %% [markdown]
# ![85251ea7-5d12-491a-ab6a-4d9731bb21d5.jpg](attachment:85251ea7-5d12-491a-ab6a-4d9731bb21d5.jpg)

# %%
s = [1,224,3231,43,56]

s.reverse()

# %%
s
# Out:
# [56, 43, 3231, 224, 1]

# %%
d = [12,3443,5432,434,67]

d
# Out:
# [12, 3443, 5432, 434, 67]

# %%
list(reversed(d))
# Out:
# [67, 434, 5432, 3443, 12]

# %%
s = 'python'

# %%
data = reversed(s)

# %%
for i in data:
    print(i,end='')
# Out:
# nohtyp

# %%
a = {'Name':'Karan',
    'Age':45,
    'Address':'Noida'}

# %%
list(a.values())
# Out:
# ['Karan', 45, 'Noida']

# %%
list(a.keys())
# Out:
# ['Name', 'Age', 'Address']

# %%
list(a)
# Out:
# ['Name', 'Age', 'Address']

# %%
[*a]
# Out:
# ['Name', 'Age', 'Address']

# %%
(*a,)
# Out:
# ('Name', 'Age', 'Address')

# %%
{*a}
# Out:
# {'Address', 'Age', 'Name'}

# %%
# python some important functions

# %%
# min()
# max()
# sum()
# sorted()
# eval()
# exec()
# help()
# id()
# type()
# print()
# bool()
# ord()
# chr()
# execfile()

# %%
# min()

a = 'python'

min(a)
# Out:
# 'h'

# %%
max(a)
# Out:
# 'y'

# %%
ord('a')
# Out:
# 97

# %%
ord('h')
# Out:
# 104

# %%
ord('y')
# Out:
# 121

# %%
print(ord('p'))
print(ord('y'))
print(ord('t'))
print(ord('h'))
print(ord('o'))
print(ord('n'))
# Out:
# 112
# 121
# 116
# 104
# 111
# 110

# %%
s = [100,234,21,32434,532,43,6757]

min(s)
# Out:
# 21

# %%
max(s)
# Out:
# 32434

# %%
s
# Out:
# [100, 234, 21, 32434, 532, 43, 6757]

# %%
sum(s)
# Out:
# 40121

# %%
s = (1,2,78.8,56-8j)

sum(s)
# Out:
# (137.8-8j)

# %%
s = {'Name':'Mohan',
    'Age':23}

sum(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 4
#       1 s = {'Name':'Mohan',
#       2     'Age':23}
# ----> 4 sum(s)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
s = {1:'One',2:"Two"}

sum(s)
# Out:
# 3

# %%
d = {'One':1,'Two':2,'Three':3}

# min(d,key=lambda)

# %%
# sorted()
# eval()
# exec()
# help()
# id()
# type()
# print()
# bool()
# ord()
# chr()
# execfile()

# %%
a = [1,23434,431,2434,6]

sorted(a,reverse=True)
# Out:
# [23434, 2434, 431, 6, 1]

# %%
s = 'python'

sorted(s)
# Out:
# ['h', 'n', 'o', 'p', 't', 'y']

# %%
eval()
# Out:
# 6

# %%
eval('2*3')
# Out:
# 6

# %%
# input()

# %%
name = input('Enter your name: ')

print(name)
# Out:
# Enter your name: Komal
# Komal

# %%
ab = input('Enter something: ')


print(ab,type(ab))
# Out:
# Enter something: True
# True <class 'str'>

# %%
s = input('Enter your name: ').upper().center(20,'*')

print(s)
# Out:
# Enter your name: lucky
# *******LUCKY********

# %%
d = eval(input('Calculate here: '))

print(d*10)
# Out:
# Calculate here: True
# 10

# %%
# 23-10+100//200**2

# %%
ord('a')
# Out:
# 97

# %%
chr(97)
# Out:
# 'a'

# %%
ord('😆')
# Out:
# 128518

# %%
chr(128999)
# Out:
# '🟧'

# %%
ord('a')
# Out:
# 97

# %%
name = input('Enter your name: ').upper()

print('😊'+name+'😊')
# Out:
# Enter your name: mohan
# 😊MOHAN😊

# %%
#  exec()
# help()
# id()
# type()
# print()
# bool()
# ord()
# chr()
# execfile()

# %%
a = 12;b = 23;c = 34;print(a+b+c)
# Out:
# 69

# %%
exec('a = 120;b = 230;c = 340;print(a+b+c)')
# Out:
# 690

# %%
b
# Out:
# 230

# %%
exec('abc = [1,2,3,4]+[1,2,3,45]')

# %%
abc
# Out:
# [1, 2, 3, 4, 1, 2, 3, 45]

# %%
type(abc)
# Out:
# list

# %%
abc.append(1234567)

# %%
abc
# Out:
# [1, 2, 3, 4, 1, 2, 3, 45, 1234567]

# %%
bool({12,2,2134,4365})
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
bool(-12345)
# Out:
# True

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %%
execfile('gaurav.py')
# Out:
# We are in Techvidya
# Enter your Name: Akshay Kumar
# How are you? Akshay Kumar Nice to meet you...
